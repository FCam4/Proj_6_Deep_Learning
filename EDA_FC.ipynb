# %% [markdown]
# <a href="https://colab.research.google.com/github/FCam4/Proj_6_Deep_Learning/blob/main/EDA_FC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore1.csv')
df_2 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore2.csv')
df_3 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore3.csv')
df_4 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore4.csv')
df_5 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore5.csv')
df_6 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore6.csv')
df_7 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore7.csv')
df_8 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore8.csv')
df_9 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore9.csv')
df_10 = pd.read_csv('https://raw.githubusercontent.com/FCam4/Proj_6_Deep_Learning/main/Google_Playstore10.csv')

# %%
df_12 = pd.concat([df_1, df_2], axis=0)
df_123 = pd.concat([df_12, df_3], axis=0)
df_1234 = pd.concat([df_123, df_4], axis=0)
df_12345 = pd.concat([df_1234, df_5], axis=0)
df_123456 = pd.concat([df_12345, df_6], axis=0)
df_1234567 = pd.concat([df_123456, df_7], axis=0)
df_12345678 = pd.concat([df_1234567, df_8], axis=0)
df_123456789 = pd.concat([df_12345678, df_9], axis=0)
df_pstore = pd.concat([df_123456789, df_10], axis=0)

# %%
df_pstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2312944 entries, 0 to 233943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %%
df_pstore.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %%
df_pstore12=df_pstore.iloc[:, 0:12]

# %%
#total apps: 2 312 944

# df_pstore12['App Name'].describe()
#df_pstore12['App Name'].isna().sum()
#valores repetidos, 2 NAs

# df_pstore12['App Id'].describe()
# df_pstore12['App Id'].isna().sum()
#nao tem valores repetidos

# df_pstore12['Category'].describe()
# df_pstore12['Category'].isna().sum()
#more common is Education, 48 different categories

#df_pstore12['Rating'].describe()
# df_pstore12['Rating'].isna().sum()
#goes from 0 to 5, there are around 22 883 NAs

# df_pstore12['Rating Count'].describe()
# df_pstore12['Rating Count'].isna().sum()
#goes from 0 to 138 557 600, there are around 22 883 NAs, in avg the apps receive around 2 864 ratings

# df_pstore12['Installs'].describe()
# df_pstore12['Installs'].value_counts()
# df_pstore12['Installs'].isna().sum()
#22 different buckets, more common is between 100+ and 500+, 107 NAs

#df_pstore12['Minimum Installs'].describe()
#df_pstore12['Minimum Installs'].isna().sum()
# 107 NAs

#df_pstore12['Maximum Installs'].describe()
#df_pstore12['Maximum Installs'].isna().sum()
# corresponds to the true nr of installs, between 0 and 12 057 630 000, avg is 320 000 installs

#df_pstore12['Free'].describe()
#df_pstore12['Free'].isna().sum()
# boolean, 2 267 876 true, 1.9% paid apps

#df_pstore12['Price'].describe()
#df_pstore12['Price'].isna().sum()
# 0.10 eur avg, 400 eur max

#df_pstore12['Currency'].describe()
#df_pstore12['Currency'].isna().sum()
# 15 currencys, most common USD (2 311 548 apps), 135 NAs

#df_pstore12['Size'].describe()
# df_pstore12['Size'].isna().sum()
# 196 NAs

# %%
#Rating count = 0 e Rating > 0

# %%
# df_pstore12['Rating Count'].value_counts()
df_pstore12['Rating'].value_counts()
# Out:
# 0.0    1059762
# 5.0     100122
# 4.2      87993
# 4.4      86304
# 4.3      83276
# 4.6      78302
# 4.5      76753
# 4.1      69723
# 4.0      67342
# 4.7      62205
# 4.8      61109
# 3.9      55684
# 3.8      53863
# 4.9      44524
# 3.7      43300
# 3.6      35989
# 3.5      31636
# 3.4      28908
# 3.3      22613
# 3.2      21485
# 3.0      17275
# 3.1      15539
# 2.8      12235
# 2.9      11522
# 2.6       9213
# 2.7       9200
# 2.5       6942
# 2.4       6051
# 2.3       5414
# 2.2       4954
# 2.0       3804
# 2.1       3675
# 1.8       2957
# 1.9       2588
# 1.7       1928
# 1.6       1644
# 1.5       1157
# 1.4       1011
# 1.0        713
# 1.3        579
# 1.2        531
# 1.1        236
# Name: Rating, dtype: int64

# %%
# condition=df_pstore12['Rating Count']==np.nan
# df_pstore12_filter=df_pstore12[condition]
# df_pstore12_filter
# df_pstore12[df_pstore12['Rating Count']==np.nan]
# df_pstore12[df_pstore12['Rating Count']=="\\N"]
df_pstore_ratingNAs = df_pstore[df_pstore['Rating Count'].isnull()]
# df[df.isnull().any(axis=1)]

# %%
# df_pstore_ratingNAs['Installs'].value_counts()
df_pstore_ratingNAs.sort_values('Maximum Installs', ascending=False)
# Out:
#                                                  App Name  \
# 218367  Camera360 - Photo Editor + Camera & Sweet selfies
# 16747                                 Vortex Cloud Gaming
# 199758                        Stickman Downhill Motocross
# 65035                                     Minecraft Earth
# 189572                           Smooth Action-Cam Slowmo
# ...                                                   ...
# 158418          Bibi.Pet Pixel and Tangram Games for Baby
# 28218                                                Heed
# 34706                         Unknown Adventure:Advancing
# 93344                                     Saratoga Falcon
# 106602     Albayt - Buy Sell Invest Properties in new way
#
#                                           App Id                 Category  \
# 218367                 vStudio.Android.Camera360              Photography
# 16747                     com.remotemyapp.vortex            Entertainment
# ...

# %%
df_pstore_ml = df_pstore.dropna(subset=['App Name','Rating', 'Rating Count', 'Installs', 'Minimum Installs', 'Maximum Installs', 'Size', 'Developer Id'])
df_pstore_ml.shape
# Out:
# (2290027, 24)

# %%
df_pstore_ml.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
df_pstore_ml['Developer Id'].describe()
df_pstore_ml['In App Purchases'].value_counts()
# Out:
# False    2097275
# True      192752
# Name: In App Purchases, dtype: int64

# %%
#df_pstore_ml['Size'].describe()
df_types=df_pstore_ml['Size'].value_counts()
df_types.head(50)
# Out:
# 11M                   62134
# 12M                   56053
# Varies with device    53048
# 13M                   48011
# 14M                   45197
# 16M                   42449
# 15M                   41287
# 17M                   37229
# 10M                   34098
# 18M                   31695
# 19M                   29705
# 21M                   29008
# 20M                   28780
# 22M                   28256
# 23M                   27328
# 24M                   25285
# 25M                   25013
# 26M                   23887
# 27M                   21821
# 28M                   21144
# 29M                   20042
# 37M                   18648
# 30M                   18616
# 31M                   18136
# 4.9M                  17965
# 32M                   17621
# 4.2M                  17413
# 3.8M                  17191
# 3.7M                  16922
# 38M                   16805
# 3.4M                  16745
# 33M                   16672
# 4.0M                  16480
# ...

# %% [markdown]
# # Graphs

# %% [markdown]
# Total nr of apps

# %%
df_pstore.shape
#2 312 944 apps
# Out:
# (2312944, 24)

# %% [markdown]
# Nr of apps free and nr of paid apps

# %%
df_pstore['Free'].value_counts()
# Out:
# True     2267876
# False      45068
# Name: Free, dtype: int64

# %% [markdown]
# Price Range

# %%
# df_pstore['Price'].describe()
df_pstore.sort_values('Price', ascending=True)
#0.19 to 400 eur
# Out:
#                                                App Name  \
# 0                                               Gakondo
# 148411                                      Raiden Raid
# 148410                                    Cha Tea House
# 148409  Manaqib Syech Abdul Qodir Aljailani Mp3 Offline
# 148408                        Radio San Joaquin 91.7 FM
# ...                                                 ...
# 124106                           Most Expensive Clicker
# 11780                                              AudD
# 157551                                          Success
# 96532                             Acid Reflux Treatment
# 82468                                      MESH Connect
#
#                                                    App Id          Category  \
# 0                                     com.ishakwe.gakondo         Adventure
# 148411                                 com.enjoy.airfight            Arcade
# ...

# %% [markdown]
# Top 10 Categories out of 32 with more apps

# %%
df_topcat=df_pstore['Category'].value_counts().head(10)
df_topcat
#32
# Out:
# Education            241090
# Music & Audio        154906
# Tools                143988
# Business             143771
# Entertainment        138276
# Lifestyle            118331
# Books & Reference    116728
# Personalization       89210
# Health & Fitness      83510
# Productivity          79698
# Name: Category, dtype: int64

# %%
#df_pstore_cat = df_pstore.groupby(['Category']).agg({'App Id': 'sum'})
# df_pstore_cat.sort_values(['App ID'], axis = 0, ascending = False, inplace = True, na_position = "first")
# df_pstore_cat=df_pstore_cat.head(10)
# sns.barplot(data=df_pstore_cat, x='Category', y='App ID')

# %% [markdown]
# Nr of released apps per year

# %%
df_pstore['years'] = df_pstore['Released'].str.strip().str[-4:]
df_pstore['years'].value_counts()
# Out:
# 2020    544882
# 2019    480665
# 2018    334566
# 2017    259685
# 2021    180508
# 2016    167112
# 2015    115432
# 2014     71815
# 2013     42476
# 2012     25747
# 2011     14362
# 2010      4641
# Name: years, dtype: int64

# %%
df_pstore_graf = df_pstore.groupby(['years']).agg({'App Id': 'count'})
df_pstore_graf.reset_index(inplace=True)
df_pstore_graf

#telemoveis apareceram
# Out:
#    years  App Id
# 0   2010    4641
# 1   2011   14362
# 2   2012   25747
# 3   2013   42476
# 4   2014   71815
# 5   2015  115432
# 6   2016  167112
# 7   2017  259685
# 8   2018  334566
# 9   2019  480665
# 10  2020  544882
# 11  2021  180508

# %%
ax_year = sns.lineplot(data=df_pstore_graf, x='years', y='App Id')
ax_year.set(xlabel='Year', ylabel='Nr_Apps')
plt.show()

#Data until June 2021

# %% [markdown]
# Interesting Insights

# %% [markdown]
# Most popular categories from most popular apps

# %%
df_pstore['Rating Count']
# Out:
# 0             0.0
# 1            64.0
# 2             0.0
# 3             5.0
# 4             0.0
#            ...
# 233939    16775.0
# 233940        0.0
# 233941        0.0
# 233942        8.0
# 233943       12.0
# Name: Rating Count, Length: 2312944, dtype: float64

# %%
apps_1mill = df_pstore[df_pstore['Rating Count'] > 1000000]
apps_1mill.sort_values('Maximum Installs', ascending=True)
# Out:
#                                 App Name  \
# 188618                          몬스터 길들이기
# 60334                            Revolut
# 31968                    LINE BROWN FARM
# 81851       ضربة معلم - لعبة الغاز مسلية
# 147973                        Tap Titans
# ...                                  ...
# 20254       Google Chrome: Fast & Secure
# 116042  Google Maps - Navigate & Explore
# 156294                            Google
# 188403                           YouTube
# 76096               Google Play services
#
#                                          App Id                 Category  \
# 188618                        com.cjenm.monster             Role Playing
# 60334                       com.revolut.revolut                  Finance
# 31968                       com.linecorp.LGFARM               Simulation
# 81851                        com.zytoona.onehit                   Puzzle
# 147973               com.gamehivecorp.taptitans             Role Playing
# ...

# %%
ax = apps_1mill.Category.value_counts().head(5).plot.barh()
ax.set(title='Comparison of Rating Count of Most Popular Apps by Category', ylabel='Rating Count')
plt.show()

# %% [markdown]
# Box plot das apps pagas

# %%
condicao = df_pstore['Price'] !=0
df_pstore_notfree = df_pstore[condicao]
df_pstore_notfree
# Out:
#                                                  App Name  \
# 273                                       Limitless Paint
# 296                         Standalone Golf GPS by Hole19
# 417                         Calculator + Widget 21 themes
# 554                                       莎士比亞11連環錯（英漢對照）
# 618                                  Theme Park Simulator
# ...                                                   ...
# 233658                              VA-Beast Essentials-2
# 233686                        Blue Infinitum Theme - Dark
# 233703                                 RPG Tears Revolude
# 233803  New Cute Kitty Cats & Animals LOVE. WAStickerApps
# 233927                              Gear Ratio Calculator
#
#                                                    App Id         Category  \
# 273                       com.bytescaffold.limitlesspaint            Tools
# 296                                   com.hole19golf.wear           Sports
# ...

# %%
df_pstore_notfree['Price'].describe()
# Out:
# count    44933.000000
# mean         5.327660
# std         18.140337
# min          0.194824
# 25%          0.990000
# 50%          1.990000
# 75%          4.490000
# max        400.000000
# Name: Price, dtype: float64

# %%
sns.boxplot(x=df_pstore_notfree['Price'])

# %%
condicao= df_pstore_notfree['Price'] < 10
df_pstore_notfree_10 = df_pstore_notfree[condicao]
sns.boxplot(x=df_pstore_notfree_10['Price'])

# %%
df_pstore['Price'].unique()
# Out:
# array([ 0.      ,  1.99    ,  4.99    , ...,  3.041816, 26.746362,
#        18.903596])

# %%
df_pstore_notfree_1=df_pstore_notfree.groupby(['Category']).agg({'Rating Count': 'sum'}).reset_index()
df_pstore_notfree_1=df_pstore_notfree_1.head(10)

values=df_pstore_notfree_1['Category']
df_pstore_notfree_top=df_pstore_notfree.query("Category in @values")
df_pstore_notfree_top['Category'].unique()

# condition=df_pstore_notfree['Category'] == 
# df_pstore_notfree.groupby(by="Category")['Rating Count'].sum()
#df_1422.groupby(['department_code', 'year']).agg({'price_sqm': 'mean'})
# Out:
# array(['Business', 'Books & Reference', 'Board', 'Card', 'Action',
#        'Adventure', 'Arcade', 'Art & Design', 'Beauty', 'Auto & Vehicles'],
#       dtype=object)

# %%
fig, ax = plt.subplots()

sns.boxplot(x='Category', y='Price', data=df_pstore_notfree_top)

ax.set_yscale('log')

ax.set(title='Comparison of Price Between Categories',
       xlabel='', ylabel='Price ($)')

# Rotate xtick labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=60)

# Set custom yticklabels
y_ticks = [0.3, 0.5, 1, 3, 5, 10, 30, 100, 300]
ax.set_yticklabels(y_ticks)

plt.show()

# %%
df_pstore.columns
# df_pstore['Content Rating'].value_counts()
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time', 'years'],
#       dtype='object')

# %%
df_pstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2312944 entries, 0 to 233943
# Data columns (total 25 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %%
plt.pie(df_pstore['Content Rating'].value_counts(),explode=[0.1,0.2,0.3,0.2,0.5,0.1],autopct='%0.2f%%',
        labels=['Everyone','Teenager','Mature 17+','Everyone 10+','Unrated','Adult only 18+'],startangle=90,radius=3,
       colors=['#00ffff','#800080','#6960ec','#fbb917','#ff00ff','#00ff00'])
plt.title('Content Rating',fontdict={'size':20,'weight':'bold'},loc='right')
plt.plot()

# import seaborn as sns

# #define data
# data = df_pstore['Content Rating'].value_counts()
# labels = ['Everyone','Teenager','Mature 17+','Everyone 10+','Unrated','Adult only 18+']

# #define Seaborn color palette to use
# colors = sns.color_palette('pastel')[0:5]

# #create pie chart
# plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
# plt.show()
# Out:
# []
